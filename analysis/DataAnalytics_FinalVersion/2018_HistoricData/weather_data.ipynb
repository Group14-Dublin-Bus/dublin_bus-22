# %%
# Import pandas, numpy, matplotlib, seaborn libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import datetime

# %%
dfweather = pd.read_csv('Custom_location_53_345035_-6_267261_62b5c8e6c91d98000ba01ceb.csv')

# %%
dfweather = dfweather[dfweather['dt_iso']>='2018-01-01'][dfweather['dt_iso']<='2018-12-31']
# Out:
# <ipython-input-3-85f09da4c9f6>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfweather = dfweather[dfweather['dt_iso']>='2018-01-01'][dfweather['dt_iso']<='2018-12-31']

# %%
dfweather.head(20)
# Out:
#               dt                         dt_iso  timezone        city_name  \
# 9014  1514764800  2018-01-01 00:00:00 +0000 UTC         0  Custom location
# 9015  1514768400  2018-01-01 01:00:00 +0000 UTC         0  Custom location
# 9016  1514772000  2018-01-01 02:00:00 +0000 UTC         0  Custom location
# 9017  1514775600  2018-01-01 03:00:00 +0000 UTC         0  Custom location
# 9018  1514779200  2018-01-01 04:00:00 +0000 UTC         0  Custom location
# 9019  1514782800  2018-01-01 05:00:00 +0000 UTC         0  Custom location
# 9020  1514786400  2018-01-01 06:00:00 +0000 UTC         0  Custom location
# 9021  1514790000  2018-01-01 07:00:00 +0000 UTC         0  Custom location
# 9022  1514793600  2018-01-01 08:00:00 +0000 UTC         0  Custom location
# 9023  1514797200  2018-01-01 09:00:00 +0000 UTC         0  Custom location
# 9024  1514800800  2018-01-01 10:00:00 +0000 UTC         0  Custom location
# ...

# %%
dfweather.tail(20)
# Out:
#                dt                         dt_iso  timezone        city_name  \
# 18030  1546142400  2018-12-30 04:00:00 +0000 UTC         0  Custom location
# 18031  1546146000  2018-12-30 05:00:00 +0000 UTC         0  Custom location
# 18032  1546149600  2018-12-30 06:00:00 +0000 UTC         0  Custom location
# 18033  1546153200  2018-12-30 07:00:00 +0000 UTC         0  Custom location
# 18034  1546156800  2018-12-30 08:00:00 +0000 UTC         0  Custom location
# 18035  1546160400  2018-12-30 09:00:00 +0000 UTC         0  Custom location
# 18036  1546164000  2018-12-30 10:00:00 +0000 UTC         0  Custom location
# 18037  1546167600  2018-12-30 11:00:00 +0000 UTC         0  Custom location
# 18038  1546171200  2018-12-30 12:00:00 +0000 UTC         0  Custom location
# 18039  1546174800  2018-12-30 13:00:00 +0000 UTC         0  Custom location
# 18040  1546178400  2018-12-30 14:00:00 +0000 UTC         0  Custom location
# ...

# %%
# saving the weather data of year 2018 to a local csv
dfweather.to_csv("weatherdata2018.csv", index=False)
