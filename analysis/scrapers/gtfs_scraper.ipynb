# %%
import pandas as pd 
import sqlite3
import sqlalchemy as sqla
from sqlalchemy import create_engine
import pymysql
import mysql
import requests
import urllib.request, json
import time
from datetime import datetime

# %%
USER='group14' 
PASSWORD=''
URL=''
PORT="3306"
DB="database-dublin-bus"
engine = create_engine("mysql+pymysql://{}:{}@{}:{}/{}".format(USER, PASSWORD, URL, PORT, DB), echo=True)
engine = create_engine("mysql+pymysql://{}:{}@{}:{}/{}".format(USER, PASSWORD, URL, PORT, DB), echo=True)

engine.execute("""CREATE TABLE if not exists gtfs(
             Time_of_db_update VARCHAR(256),
             TripId VARCHAR(256),
             RouteId VARCHAR(256),
             StartTime VARCHAR(256),
             StartDate VARCHAR(256),
             StopSequence VARCHAR(256),
             StopId VARCHAR(256),
             Arr_delay VARCHAR(256),
             Dep_delay VARCHAR(256))
             """)
        
db = pymysql.connect(
host=URL,
user=USER,
password=PASSWORD,
port=3306,
database=DB)
#current_time = now.strftime("%H:%M")

url = "https://api.nationaltransport.ie/gtfsr/v1?format=json"

hdr ={
        'Cache-Control': 'no-cache',
        'x-api-key': 'd01bfcfc5bdf41fe82eddd91ca1dd3e1'
}

req = urllib.request.Request(url, headers=hdr)
req.get_method = lambda: 'GET'
response = urllib.request.urlopen(req)
print(response.getcode())
f=(response.read())
jsonResponse = json.loads(f.decode('utf-8'))
        #print("h",len(jsonResponse['Entity']))
        
        
        
for x in jsonResponse["Entity"]:
            if "StopTimeUpdate" in x["TripUpdate"]:
             #print("ent")
             for i in x["TripUpdate"]["StopTimeUpdate"]:
      #      print("i")
                if "Arrival" in i and "Departure" in i:
                   # print("YIPPPEEE")
                    if "Delay" in i["Arrival"] and "Delay" in i["Departure"]:
                
                       #ff=ff+1

                        #for i in x["TripUpdate"]["StopTimeUpdate"]:

                           print("i")

                           gt=(
                           str(jsonResponse["Header"]["Timestamp"]),
                           str(x["TripUpdate"]["Trip"]["TripId"]),
                           str(x["TripUpdate"]["Trip"]["StartTime"]),
                           str(x["TripUpdate"]["Trip"]["StartDate"]),
                           str(x["TripUpdate"]["Trip"]["RouteId"]),
                            # print("yes",str(x["TripUpdate"]["Trip"]["RouteId"]),
                           str(i["StopSequence"]),
                           str(i["StopId"]),
                           str(i["Arrival"]["Delay"]),
                           str(i["Departure"]["Delay"]))
                        
                        

                       #)
                       #str(i["StopSequence"]),
                       #str(i["StopId"])
                   #   if "Arrival" in x:
                       #arr=""
                      # arr=str(i["Arrival"]["Delay"])
                    #  if "Departure" in x:
                      # dep=""
                      # dep=str(i["Departure"]["Delay"])   
                         
                           gtfs = gt
                           #print(len(gtfs))
                           try:   
                               print("INSERTING")
                               ins=("INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)" 
                                      "VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)")
                               engine.execute(ins,gtfs) 
                               print("XXXXXXXXXXXXXX",gtfs)
                                 #TripId VARCHAR(256),
 
                       
                    
                    
                     
                             #cursor.execute(sql1)
                             #engine.execute(sql1)
                               db.commit()
                               print("Insert successfully")
                       
                    
                    
                           except:
                                print("Insert WRONG")
                       #db.close() 
    
                      # print(ff)
                       #return (gtfs)
# Out:
# 2022-07-22 16:31:47,553 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-07-22 16:31:47,553 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-22 16:31:47,665 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-07-22 16:31:47,665 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-22 16:31:47,720 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-07-22 16:31:47,722 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-22 16:31:47,774 INFO sqlalchemy.engine.Engine CREATE TABLE if not exists gtfs(
#              Time_of_db_update VARCHAR(256),
#              TripId VARCHAR(256),
#              RouteId VARCHAR(256),
#              StartTime VARCHAR(256),
#              StartDate VARCHAR(256),
#              StopSequence VARCHAR(256),
#              StopId VARCHAR(256),
#              Arr_delay VARCHAR(256),
#              Dep_delay VARCHAR(256))
#
# 2022-07-22 16:31:47,776 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-22 16:31:47,813 INFO sqlalchemy.engine.Engine COMMIT
# 200
# i
# INSERTING
# 2022-07-22 16:31:55,813 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:55,813 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '2', '8460B5228101', '900', '900')
# 2022-07-22 16:31:55,869 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '2', '8460B5228101', '900', '900')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:55,957 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:55,957 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '3', '8470B5560901', '600', '600')
# 2022-07-22 16:31:56,025 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '3', '8470B5560901', '600', '600')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:56,107 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:56,107 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '6', '8470BB555621', '420', '420')
# 2022-07-22 16:31:56,168 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '6', '8470BB555621', '420', '420')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:56,257 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:56,257 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '7', '8470B357911', '360', '360')
# 2022-07-22 16:31:56,317 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '7', '8470B357911', '360', '360')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:56,406 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:56,406 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '8', '8470B6353501', '420', '600')
# 2022-07-22 16:31:56,465 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '8', '8470B6353501', '420', '600')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:56,571 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:56,571 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '9', '8360B357931', '240', '240')
# 2022-07-22 16:31:56,620 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '9', '8360B357931', '240', '240')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:56,691 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:56,707 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '10', '8360B6353401', '300', '540')
# 2022-07-22 16:31:56,742 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '10', '8360B6353401', '300', '540')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:56,891 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:56,891 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '11', '8360B6311401', '660', '660')
# 2022-07-22 16:31:56,932 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '11', '8360B6311401', '660', '660')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:57,036 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:57,036 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '13', '8360B609521', '660', '1200')
# 2022-07-22 16:31:57,079 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '13', '8360B609521', '660', '1200')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:57,185 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:57,186 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '14', '8360B6095501', '600', '600')
# 2022-07-22 16:31:57,310 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '14', '8360B6095501', '600', '600')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:57,426 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:57,426 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '15', '8400B6350301', '8520', '7680')
# 2022-07-22 16:31:57,493 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '15', '8400B6350301', '8520', '7680')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:57,608 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:57,609 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '16', '8410B3578101', '8940', '8940')
# 2022-07-22 16:31:57,645 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026245.5.10-51-e20-1.114.I', '10:05:00', '20220722', '10-51-e20-1', '16', '8410B3578101', '8940', '8940')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:57,773 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:57,775 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '2', '8460B5228101', '60', '180')
# 2022-07-22 16:31:57,822 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '2', '8460B5228101', '60', '180')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:57,922 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:57,923 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '3', '8470B551411', '300', '300')
# 2022-07-22 16:31:57,963 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '3', '8470B551411', '300', '300')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:58,062 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:58,064 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '4', '8470B521211', '360', '360')
# 2022-07-22 16:31:58,100 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '4', '8470B521211', '360', '360')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:58,204 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:58,205 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '5', '8470B532361', '600', '600')
# 2022-07-22 16:31:58,240 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '5', '8470B532361', '600', '600')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:58,329 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:58,330 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '6', '8490B631111', '480', '480')
# 2022-07-22 16:31:58,366 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '6', '8490B631111', '480', '480')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:58,463 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:58,466 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '7', '8490B532371', '420', '420')
# 2022-07-22 16:31:58,504 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '7', '8490B532371', '420', '420')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:58,581 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:58,581 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '8', '8490B151051', '300', '300')
# 2022-07-22 16:31:58,638 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '8', '8490B151051', '300', '300')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:58,730 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:58,730 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '9', '8490B160001', '420', '540')
# 2022-07-22 16:31:58,796 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '9', '8490B160001', '420', '540')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:58,906 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:58,906 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '10', '8490B532381', '420', '420')
# 2022-07-22 16:31:58,948 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '10', '8490B532381', '420', '420')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:59,064 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:59,064 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '11', '8490B5530801', '240', '240')
# 2022-07-22 16:31:59,112 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '11', '8490B5530801', '240', '240')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:59,206 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:59,206 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '13', '8510B552221', '180', '180')
# 2022-07-22 16:31:59,250 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '13', '8510B552221', '180', '180')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:59,356 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:59,359 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '14', '8510B552241', '0', '120')
# 2022-07-22 16:31:59,418 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '14', '8510B552241', '0', '120')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:59,514 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:59,516 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '15', '8510B550211', '240', '240')
# 2022-07-22 16:31:59,560 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '15', '8510B550211', '240', '240')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:59,670 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:59,670 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '17', '8510B558181', '180', '180')
# 2022-07-22 16:31:59,726 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '17', '8510B558181', '180', '180')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:59,830 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:59,830 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '18', '8510B5550801', '-180', '-1380')
# 2022-07-22 16:31:59,884 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '18', '8510B5550801', '-180', '-1380')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:31:59,955 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:31:59,955 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '19', '8510B551571', '300', '300')
# 2022-07-22 16:32:00,003 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '19', '8510B551571', '300', '300')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:00,104 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:00,106 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '20', '8510B555131', '180', '180')
# 2022-07-22 16:32:00,148 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '20', '8510B555131', '180', '180')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:00,237 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:00,237 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '21', '8510B1408901', '180', '480')
# 2022-07-22 16:32:00,298 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '21', '8510B1408901', '180', '480')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:00,454 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:00,456 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '23', '8530B6358001', '600', '780')
# 2022-07-22 16:32:00,503 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '23', '8530B6358001', '600', '780')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:00,616 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:00,616 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '25', '8530B1324801', '720', '960')
# 2022-07-22 16:32:00,652 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '25', '8530B1324801', '720', '960')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:00,741 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:00,741 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '26', '8530B1558201', '1380', '1500')
# 2022-07-22 16:32:00,798 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '26', '8530B1558201', '1380', '1500')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:00,874 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:00,874 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '27', '8530B6358301', '1680', '1860')
# 2022-07-22 16:32:00,920 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '27', '8530B6358301', '1680', '1860')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:00,991 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:00,991 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '28', '8530B158221', '2880', '2880')
# 2022-07-22 16:32:01,049 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '28', '8530B158221', '2880', '2880')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:01,146 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:01,147 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '29', '8530B1558401', '2820', '3180')
# 2022-07-22 16:32:01,205 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '29', '8530B1558401', '2820', '3180')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:01,292 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:01,292 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '30', '8530B1559601', '3240', '3240')
# 2022-07-22 16:32:01,337 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '30', '8530B1559601', '3240', '3240')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:01,424 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:01,426 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '31', '8530B1581501', '3300', '3300')
# 2022-07-22 16:32:01,484 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026330.5.10-64-e20-1.167.I', '10:30:00', '20220722', '10-64-e20-1', '31', '8530B1581501', '3300', '3300')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:01,619 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:01,621 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '2', '8530B6358201', '480', '480')
# 2022-07-22 16:32:01,660 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '2', '8530B6358201', '480', '480')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:01,774 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:01,777 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '3', '8530B158191', '300', '420')
# 2022-07-22 16:32:01,813 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '3', '8530B158191', '300', '420')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:01,942 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:01,945 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '4', '8530B158201', '300', '360')
# 2022-07-22 16:32:01,984 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '4', '8530B158201', '300', '360')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:02,049 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:02,064 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '5', '8530B158221', '300', '300')
# 2022-07-22 16:32:02,107 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '5', '8530B158221', '300', '300')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:02,195 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:02,195 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '6', '8530B1558401', '0', '0')
# 2022-07-22 16:32:02,274 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '6', '8530B1558401', '0', '0')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:02,365 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:02,365 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '7', '8530B1559601', '600', '600')
# 2022-07-22 16:32:02,399 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '7', '8530B1559601', '600', '600')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:02,494 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:02,496 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '8', '8530B141301', '900', '1080')
# 2022-07-22 16:32:02,534 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '8', '8530B141301', '900', '1080')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:02,632 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:02,632 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '9', '8530B1558201', '840', '1380')
# 2022-07-22 16:32:02,667 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '9', '8530B1558201', '840', '1380')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:02,772 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:02,772 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '10', '8530B140811', '2040', '2220')
# 2022-07-22 16:32:02,838 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '10', '8530B140811', '2040', '2220')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:02,938 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:02,938 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '11', '8530B140021', '2160', '2160')
# 2022-07-22 16:32:02,990 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '11', '8530B140021', '2160', '2160')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:03,071 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:03,071 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '12', '8530B559321', '2100', '2280')
# 2022-07-22 16:32:03,111 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '12', '8530B559321', '2100', '2280')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:03,186 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:03,186 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '13', '8530B635841', '2340', '2340')
# 2022-07-22 16:32:03,230 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '13', '8530B635841', '2340', '2340')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:03,312 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:03,314 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '14', '8510B140061', '1620', '1620')
# 2022-07-22 16:32:03,371 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '14', '8510B140061', '1620', '1620')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:03,472 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:03,473 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '15', '8510B140071', '1260', '1260')
# 2022-07-22 16:32:03,515 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '15', '8510B140071', '1260', '1260')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:03,605 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:03,607 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '16', '8510B5550901', '720', '720')
# 2022-07-22 16:32:03,639 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '16', '8510B5550901', '720', '720')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:03,723 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:03,724 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '17', '8510B5550801', '0', '1860')
# 2022-07-22 16:32:03,761 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '17', '8510B5550801', '0', '1860')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:03,844 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:03,845 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '18', '8510B5552301', '2040', '2220')
# 2022-07-22 16:32:03,880 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '18', '8510B5552301', '2040', '2220')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:03,973 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:03,974 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '19', '8510B5520001', '2340', '2340')
# 2022-07-22 16:32:04,011 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '19', '8510B5520001', '2340', '2340')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:04,092 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:04,092 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '20', '8490B141641', '2340', '2400')
# 2022-07-22 16:32:04,131 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '20', '8490B141641', '2340', '2400')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:04,234 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:04,235 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '21', '8490B5530801', '2340', '2340')
# 2022-07-22 16:32:04,269 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '21', '8490B5530801', '2340', '2340')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:04,353 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:04,354 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '22', '8490B5531001', '2640', '2640')
# 2022-07-22 16:32:04,407 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '22', '8490B5531001', '2640', '2640')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:04,509 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:04,510 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '23', '8490B5553801', '2520', '2520')
# 2022-07-22 16:32:04,557 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '23', '8490B5553801', '2520', '2520')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:04,671 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:04,686 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '24', '8490B5553701', '2940', '2940')
# 2022-07-22 16:32:04,744 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '24', '8490B5553701', '2940', '2940')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:04,845 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:04,847 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '25', '8490B5320301', '3000', '3000')
# 2022-07-22 16:32:04,879 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026350.5.10-64-e20-1.152.O', '11:10:00', '20220722', '10-64-e20-1', '25', '8490B5320301', '3000', '3000')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:04,954 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:04,956 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '2', '8510BB556291', '0', '0')
# 2022-07-22 16:32:05,014 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '2', '8510BB556291', '0', '0')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:05,104 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:05,104 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '3', '8500B5557901', '60', '120')
# 2022-07-22 16:32:05,164 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '3', '8500B5557901', '60', '120')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:05,260 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:05,262 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '4', '8480B5578101', '840', '900')
# 2022-07-22 16:32:05,290 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '4', '8480B5578101', '840', '900')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:05,375 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:05,375 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '5', '8480B556311', '720', '720')
# 2022-07-22 16:32:05,419 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '5', '8480B556311', '720', '720')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:05,512 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:05,513 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '6', '8290B556281', '660', '720')
# 2022-07-22 16:32:05,575 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '6', '8290B556281', '660', '720')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:05,689 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:05,690 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '7', '8290B1357701', '1080', '1260')
# 2022-07-22 16:32:05,730 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '7', '8290B1357701', '1080', '1260')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:05,836 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:05,836 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '8', '8290B1416701', '1140', '1140')
# 2022-07-22 16:32:05,871 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '8', '8290B1416701', '1140', '1140')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:05,968 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:05,968 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '9', '8290B104421', '1080', '1140')
# 2022-07-22 16:32:06,011 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '9', '8290B104421', '1080', '1140')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:06,083 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:06,086 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '10', '8330B104431', '1080', '1140')
# 2022-07-22 16:32:06,131 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '10', '8330B104431', '1080', '1140')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:06,215 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:06,215 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '11', '8330B104441', '1080', '1080')
# 2022-07-22 16:32:06,249 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '11', '8330B104441', '1080', '1080')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:06,340 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:06,341 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '12', '8330B1387901', '1320', '1320')
# 2022-07-22 16:32:06,369 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '12', '8330B1387901', '1320', '1320')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:06,444 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:06,446 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '13', '8330B1357501', '3900', '3900')
# 2022-07-22 16:32:06,490 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '13', '8330B1357501', '3900', '3900')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:06,574 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:06,575 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '14', '8230B1034401', '1140', '1140')
# 2022-07-22 16:32:06,625 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '14', '8230B1034401', '1140', '1140')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:06,725 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:06,726 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '15', '8230B1034501', '1260', '1260')
# 2022-07-22 16:32:06,769 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025902.5.10-23-e20-1.68.I', '12:15:00', '20220722', '10-23-e20-1', '15', '8230B1034501', '1260', '1260')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:06,862 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# ...
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:56,794 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:56,795 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '16', '8260GD10387', '-60', '0')
# 2022-07-22 16:32:56,842 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '16', '8260GD10387', '-60', '0')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:56,943 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:56,944 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '18', '8260B1041601', '-120', '540')
# 2022-07-22 16:32:56,992 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '18', '8260B1041601', '-120', '540')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:57,090 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:57,090 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '20', '8260B1041801', '480', '480')
# 2022-07-22 16:32:57,139 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '20', '8260B1041801', '480', '480')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:57,240 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:57,240 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '21', '8260B1041901', '420', '660')
# 2022-07-22 16:32:57,298 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '21', '8260B1041901', '420', '660')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:57,400 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:57,401 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '22', '8260B1370001', '720', '840')
# 2022-07-22 16:32:57,437 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '22', '8260B1370001', '720', '840')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:57,542 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:57,542 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '23', '8260B1042001', '900', '900')
# 2022-07-22 16:32:57,590 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '23', '8260B1042001', '900', '900')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:57,659 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:57,675 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '24', '8260B1042101', '1020', '1080')
# 2022-07-22 16:32:57,720 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '24', '8260B1042101', '1020', '1080')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:57,822 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:57,823 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '25', '8260B1042201', '1020', '1020')
# 2022-07-22 16:32:57,867 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '25', '8260B1042201', '1020', '1020')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:57,972 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:57,972 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '26', '8260B1042301', '960', '960')
# 2022-07-22 16:32:58,030 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '26', '8260B1042301', '960', '960')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:58,124 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:58,124 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '28', '8260B1042501', '960', '1020')
# 2022-07-22 16:32:58,169 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '28', '8260B1042501', '960', '1020')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:58,270 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:58,271 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '29', '8260B1042601', '1080', '1080')
# 2022-07-22 16:32:58,312 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '29', '8260B1042601', '1080', '1080')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:58,391 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:58,392 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '32', '8260B1042901', '1500', '1560')
# 2022-07-22 16:32:58,420 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '2543.y1002.17-126-1-cm1-1.151.I', '14:21:00', '20220722', '17-126-1-cm1-1', '32', '8260B1042901', '1500', '1560')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:58,491 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:58,492 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '2', '8380B2347701', '300', '300')
# 2022-07-22 16:32:58,535 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '2', '8380B2347701', '300', '300')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:58,650 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:58,653 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '3', '8380B6310601', '120', '420')
# 2022-07-22 16:32:58,706 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '3', '8380B6310601', '120', '420')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:58,811 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:58,814 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '4', '8380B2323801', '480', '480')
# 2022-07-22 16:32:58,856 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '4', '8380B2323801', '480', '480')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:58,954 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:58,955 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '5', '8380B2336201', '300', '300')
# 2022-07-22 16:32:58,996 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '5', '8380B2336201', '300', '300')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:59,075 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:59,075 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '6', '8380B6311801', '360', '360')
# 2022-07-22 16:32:59,136 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '6', '8380B6311801', '360', '360')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:59,223 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:59,223 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '7', '8380B3577901', '480', '480')
# 2022-07-22 16:32:59,286 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '7', '8380B3577901', '480', '480')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:59,375 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:59,375 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '8', '8380B609661', '600', '720')
# 2022-07-22 16:32:59,409 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '8', '8380B609661', '600', '720')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:59,491 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:59,491 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '9', '8410B609641', '900', '900')
# 2022-07-22 16:32:59,529 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '9', '8410B609641', '900', '900')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:59,620 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:59,621 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '10', '8400B6350301', '660', '0')
# 2022-07-22 16:32:59,665 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '10', '8400B6350301', '660', '0')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:59,756 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:59,756 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '11', '8360B3553301', '-120', '-120')
# 2022-07-22 16:32:59,819 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4025114.5.10-51-e20-1.115.O', '14:25:00', '20220722', '10-51-e20-1', '11', '8360B3553301', '-120', '-120')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:32:59,910 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:32:59,910 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026381.5.10-72-e20-1.198.O', '14:25:00', '20220722', '10-72-e20-1', '2', '8410B3510701', '600', '600')
# 2022-07-22 16:32:59,960 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026381.5.10-72-e20-1.198.O', '14:25:00', '20220722', '10-72-e20-1', '2', '8410B3510701', '600', '600')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:33:00,059 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:33:00,060 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026381.5.10-72-e20-1.198.O', '14:25:00', '20220722', '10-72-e20-1', '6', '8420B155481', '360', '480')
# 2022-07-22 16:33:00,104 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026381.5.10-72-e20-1.198.O', '14:25:00', '20220722', '10-72-e20-1', '6', '8420B155481', '360', '480')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:33:00,210 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:33:00,210 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026381.5.10-72-e20-1.198.O', '14:25:00', '20220722', '10-72-e20-1', '9', '8420B3339101', '660', '660')
# 2022-07-22 16:33:00,253 INFO sqlalchemy.engine.Engine COMMIT
# XXXXXXXXXXXXXX ('1658503899', '4026381.5.10-72-e20-1.198.O', '14:25:00', '20220722', '10-72-e20-1', '9', '8420B3339101', '660', '660')
# Insert successfully
# i
# INSERTING
# 2022-07-22 16:33:00,591 INFO sqlalchemy.engine.Engine INSERT INTO gtfs(Time_of_db_update,TripId,StartTime,StartDate,RouteId,StopSequence,StopId,Arr_delay,Dep_delay)VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-07-22 16:33:00,591 INFO sqlalchemy.engine.Engine [raw sql] ('1658503899', '4026381.5.10-72-e20-1.198.O', '14:25:00', '20220722', '10-72-e20-1', '10', '8320B1521001', '960', '960')
# 2022-07-22 16:33:00,622 INFO sqlalchemy.engine.Engine COMMIT
